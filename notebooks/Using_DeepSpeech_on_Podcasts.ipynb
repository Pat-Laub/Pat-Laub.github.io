# %% [markdown]
# # Run deepspeech over the last episodes

# %%
import os
from os.path import exists, join, basename, splitext

# !apt-get install -qq sox
# !pip install -q deepspeech-gpu

if not exists('deepspeech-0.9.3-models.pbmm'):
  # !wget https://github.com/mozilla/DeepSpeech/releases/download/v0.9.3/deepspeech-0.9.3-models.pbmm

if not exists('deepspeech-0.9.3-models.scorer'):
  # !wget https://github.com/mozilla/DeepSpeech/releases/download/v0.9.3/deepspeech-0.9.3-models.scorer

# %%
for epNum in range(427, 406, -1):
  if not exists(f"Syntax_-_{epNum}.mp3"):
    url = f"https://traffic.libsyn.com/secure/syntax/Syntax_-_{epNum}.mp3"
    # !wget {url}
# Out:
# --2022-02-08 01:44:32--  https://traffic.libsyn.com/secure/syntax/Syntax_-_424.mp3
# Resolving traffic.libsyn.com (traffic.libsyn.com)... 204.16.246.216
# Connecting to traffic.libsyn.com (traffic.libsyn.com)|204.16.246.216|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-02-08 01:44:33 ERROR 404: Not Found.
#
# --2022-02-08 01:44:33--  https://traffic.libsyn.com/secure/syntax/Syntax_-_421.mp3
# Resolving traffic.libsyn.com (traffic.libsyn.com)... 204.16.246.216
# Connecting to traffic.libsyn.com (traffic.libsyn.com)|204.16.246.216|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-02-08 01:44:34 ERROR 404: Not Found.

# %%
for epNum in range(427, 406, -1):
  podName = f"Syntax_-_{epNum}"
  if not exists(podName + ".wav"):
    # !ffmpeg -i {podName}.mp3 {podName}.wav

  # !deepspeech --model deepspeech-0.9.3-models.pbmm --scorer deepspeech-0.9.3-models.scorer --audio {podName}.wav
# Out:
# 2022-02-08 01:44:38.608681: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Loading model from file deepspeech-0.9.3-models.pbmm
# TensorFlow: v2.3.0-6-g23ad988
# DeepSpeech: v0.9.3-0-gf2e9c85
# 2022-02-08 01:44:38.857089: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-08 01:44:38.858291: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-02-08 01:44:38.890390: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
